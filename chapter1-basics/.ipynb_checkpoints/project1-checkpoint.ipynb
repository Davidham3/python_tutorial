# %% [markdown]
# # project1 绘制词云
# ## 对project1/romeo.txt做一些简单统计
#
# 首先执行下面这条命令安装wordcloud，这是绘制词云的一个工具
# pip install -i https://pypi.tuna.tsinghua.edu.cn/simple wordcloud
#
# ### part1
# 1. 求全文一共包含多少个字符（含空格、符号等）
#
# 2. 求全文一共多少行
#
# 2. 打印前5行
#
# 3. 第一行一共多少个单词？
#
# 4. 统计'Romeo'这个单词出现的次数(区分大小写)
#
# 5. 不区分大小写的统计romeo这个单词出现的次数
#
# ### part2
#
# 6. 使用**空格**将全文分割后(split)得到的列表里面有多少个元素？该列表存为list1
#
# 8. 对上述列表中的元素进行统计，求出每个元素的出现次数，存放至一个字典word_count1中
#
# 9. 求上述列表中出现次数最多的10个元素和它们出现的次数
#
# ### part3
#
# 10. 将全文转换为**小写字母**后，使用**'\n'**分割后得到一个新的列表，对该列表中的每个元素使用**空格**分割，分割后的所有元素，存放到列表list2中
#
# 11. 读取project1目录下stopwords1.txt到stopwords5.txt这5个文件，这两个文件中的单词存放到集合stopwords中
#
# 12. 删除list2中属于stopwords的元素
#
# 13. 删除list2中的空字符串''
#
# 14. 对list2中的元素进行统计，求出每个元素的出现次数，存放至一个字典word_count2中
#
# 14. 求list2中出现次数最多的10个元素和它们出现的次数
#
# ### part4
#
# 15. 在写好的代码后加入如下代码：
#   ```
#   from wordcloud import WordCloud
#   from wordcloud import ImageColorGenerator
#   import matplotlib.pyplot as plt
#   from scipy.misc import imread
#
#   back_coloring = imread("project1/background.jpg")
#   print('building wordcloud...')
#   wc = WordCloud(background_color = "white", max_words = 2000, max_font_size = 50, mask = back_coloring,
#                 random_state = 2, width=1000, height=860, margin=2)
#   wc.generate_from_frequencies(word_count)
#   print('wordcloud built!')
#
#   plt.figure(figsize=(10, 8))
#   plt.subplot(131)
#   plt.imshow(wc)
#   plt.axis("off")
#
#   plt.subplot(132)
#   image_colors = ImageColorGenerator(back_coloring)
#   plt.imshow(wc.recolor(color_func=image_colors))
#   plt.axis("off")
#
#   plt.subplot(133)
#   plt.imshow(back_coloring)
#   plt.axis("off")
#   plt.show()
#   ```
#
# ### part5
# 1. 请自行学习stopwords
# 2. 思考：part3第一步的处理方式与part2的第一步有什么不同？
# 3. 思考：如果将part3的第二步，stopwords换成列表，会有什么影响？
# 4. 思考：为什么part3要删除stopwords
